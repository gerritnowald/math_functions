# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## data

# %%
data = {
'21 03' : 61  ,
'21 04' : 81  ,
'21 05' : 91  ,
'21 06' : 122 ,
'21 07' : 73  ,
'21 08' : 77  ,
'21 09' : 124 ,
'21 10' : 59  ,
'21 11' : 72  ,
'21 12' : 67  ,
'22 01' : 59  ,
'22 02' : 51  ,
'22 03' : 60  ,
'22 04' : 81  ,
'22 05' : 56  ,
'22 06' : 51  ,
'22 07' : 63  ,
'22 08' : 60  ,
'22 09' : 43  ,
'22 10' : 52  ,
'22 11' : 43  ,
'22 12' : 43  ,
'23 01' : 48  ,
'23 02' : 36  ,
'23 03' : 35  ,
'23 03' : 41  ,
}

# %% [markdown]
# ## convert to dataframe

# %%
data = pd.DataFrame.from_dict(data, orient='index')

# %% [markdown]
# ## plot

# %%
data.plot()
plt.xlabel('Monat')
plt.ylabel('tägliche Nutzung / min')
plt.show()
